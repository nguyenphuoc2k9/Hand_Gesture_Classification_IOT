# %%
import os
import cv2
import yaml
import torch
import numpy as np
import pandas as pd
from  torch import nn
import mediapipe as mp
from torch import optim
from datetime import datetime
from torchmetrics import Accuracy
from torch.utils.data import Dataset

# %% [markdown]
# # Run

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        list_label = label_dict_from_config_file("hand_gesture.yaml")

        self.linear_relu_stack = nn.Sequential(
            nn.Linear(63,128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Linear(128,128),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(128,128),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(128,128),
            nn.ReLU(),
            nn.Dropout(0.6),
            nn.Linear(128,len(list_label))
        )
    def forward(self, x):
        x = self.flatten(x)
        x = self.linear_relu_stack(x)
        return x
    def predict(self,x,threshold=0.8):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        chosen_ind = torch.argmax(softmax_prob,dim=1)
        return torch.where(softmax_prob[0,chosen_ind]>threshold,chosen_ind,-1)

    def predict_with_known_class(self,x):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        return torch.argmax(softmax_prob,dim=1)

    def score(self,logits):
        return -torch.amax(logits,dim=1)

# %%
def label_dict_from_config_file(relative_path):
    with open(relative_path,"r") as f:
       label_tag = yaml.full_load(f)["gestures"]
    return label_tag

# %%
class HandLandmarksDetector():
    def __init__(self) -> None:
        self.mp_drawing = mp.solutions.drawing_utils
        self.mp_drawing_styles = mp.solutions.drawing_styles
        self.mp_hands = mp.solutions.hands
        self.detector = self.mp_hands.Hands(False,max_num_hands=1,min_detection_confidence=0.5)

    def detectHand(self,frame):
        hands = []
        frame = cv2.flip(frame, 1)
        annotated_image = frame.copy()
        results = self.detector.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        if results.multi_hand_landmarks is not None:
            for hand_landmarks in results.multi_hand_landmarks:
                hand = []
                self.mp_drawing.draw_landmarks(
                    annotated_image,
                    hand_landmarks,
                    self.mp_hands.HAND_CONNECTIONS,
                    self.mp_drawing_styles.get_default_hand_landmarks_style(),
                    self.mp_drawing_styles.get_default_hand_connections_style())
                for landmark in hand_landmarks.landmark:
                    x,y,z = landmark.x,landmark.y,landmark.z
                    hand.extend([x,y,z])
            hands.append(hand)
        return hands,annotated_image

# %%
class CustomImageDataset(Dataset):
    def __init__(self, data_file):
        self.data = pd.read_csv(data_file)
        self.labels = torch.from_numpy(self.data.iloc[:,0].to_numpy())

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        one_hot_label = self.labels[idx]
        torch_data = torch.from_numpy(self.data.iloc[idx,1:].to_numpy(dtype=np.float32))
        return torch_data, one_hot_label

# %%
class EarlyStopper:
    def __init__(self, patience=1, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.watched_metrics = np.inf

    def early_stop(self, current_value):
        if current_value < self.watched_metrics:
            self.watched_metrics = current_value
            self.counter = 0
        elif current_value > (self.watched_metrics + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
def train(trainloader, val_loader, model, loss_function, early_stopper, optimizer):
    # add auroc score
    best_vloss = 1_000_000
    timestamp = datetime.now().strftime('%d-%m %H:%M')
    for epoch in range(300):
        #training step
        model.train(True)
        running_loss = 0.0
        acc_train = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for batch_number,data in enumerate(trainloader):
            inputs,labels = data

            optimizer.zero_grad()

            preds = model(inputs)

            loss = loss_function(preds,labels)
            loss.backward()
            optimizer.step()

            acc_train.update(model.predict_with_known_class(inputs), labels)
            running_loss += loss.item()
        avg_loss = running_loss / len(trainloader)
        # validating step
        model.train(False)
        running_vloss = 0.0
        acc_val = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for i, vdata in enumerate(val_loader):
            vinputs, vlabels = vdata
            preds = model(vinputs)
            vloss = loss_function(preds, vlabels)
            running_vloss += vloss.item()
            acc_val.update(model.predict_with_known_class(vinputs), vlabels)

        print(f"Epoch {epoch}: ")
        print(f"Accuracy train:{acc_train.compute().item()}, val:{acc_val.compute().item()}")
        avg_vloss = running_vloss / len(val_loader)
        print('LOSS train {} valid {}'.format(avg_loss, avg_vloss))
        print('Training vs. Validation Loss',
                        { 'Training' : avg_loss, 'Validation' : avg_vloss },
                        epoch + 1)
        print('Training vs. Validation accuracy',
                        { 'Training' : acc_train.compute().item()
                        , 'Validation' : acc_val.compute().item() },
                        epoch + 1)

        # Track best performance, and save the model's state
        if avg_vloss < best_vloss:
            best_vloss = avg_vloss
            best_model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_best'
            torch.save(model.state_dict(), best_model_path)

        if early_stopper.early_stop(avg_vloss):
            print(f"Stoping at epoch {epoch},minimum: {early_stopper.watched_metrics}")



    model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_last'
    torch.save(model.state_dict(), model_path)

    print(acc_val.compute())
    return model, best_model_path

# %%
DATA_FOLDER_PATH="./data/"
LIST_LABEL = label_dict_from_config_file("hand_gesture.yaml")
train_path = os.path.join(DATA_FOLDER_PATH,"landmark_train.csv")
val_path = os.path.join(DATA_FOLDER_PATH,"landmark_val.csv")
save_path = './models'
os.makedirs(save_path,exist_ok=True)

trainset = CustomImageDataset(train_path)

trainloader = torch.utils.data.DataLoader(trainset,batch_size=40,shuffle=True)
valset = CustomImageDataset(os.path.join(val_path))
val_loader = torch.utils.data.DataLoader(valset,batch_size=50, shuffle=False)

model = NeuralNetwork()
loss_function = nn.CrossEntropyLoss()
early_stopper = EarlyStopper(patience=30,min_delta=0.01)
'''Hoàn thành code để thực hiện cấu hình Adam optimizer cho các tham số của
model với tốc độ học là 0.0001
'''
optimizer =optim.Adam(model.parameters(),lr=0.0001)


model, best_model_path = train(trainloader, val_loader, model, loss_function, early_stopper, optimizer)
# Out:
# Epoch 0:
# Accuracy train:0.2041216939687729, val:0.17747440934181213
# LOSS train 1.616444156720088 valid 1.6050517360369365
# Training vs. Validation Loss {'Training': 1.616444156720088, 'Validation': 1.6050517360369365} 1
# Training vs. Validation accuracy {'Training': 0.2041216939687729, 'Validation': 0.17747440934181213} 1
# Epoch 1:
# Accuracy train:0.2541707456111908, val:0.255972683429718
# LOSS train 1.5917007877276494 valid 1.5814577738444011
# Training vs. Validation Loss {'Training': 1.5917007877276494, 'Validation': 1.5814577738444011} 2
# Training vs. Validation accuracy {'Training': 0.2541707456111908, 'Validation': 0.255972683429718} 2
# Epoch 2:
# Accuracy train:0.32482826709747314, val:0.3993174135684967
# LOSS train 1.567257638160999 valid 1.5621092518170674
# Training vs. Validation Loss {'Training': 1.567257638160999, 'Validation': 1.5621092518170674} 3
# Training vs. Validation accuracy {'Training': 0.32482826709747314, 'Validation': 0.3993174135684967} 3
# Epoch 3:
# Accuracy train:0.3964671194553375, val:0.5017064809799194
# LOSS train 1.536042103400597 valid 1.5321168104807537
# Training vs. Validation Loss {'Training': 1.536042103400597, 'Validation': 1.5321168104807537} 4
# Training vs. Validation accuracy {'Training': 0.3964671194553375, 'Validation': 0.5017064809799194} 4
# Epoch 4:
# Accuracy train:0.4367026388645172, val:0.5187713503837585
# LOSS train 1.4864926750843341 valid 1.481806794802348
# Training vs. Validation Loss {'Training': 1.4864926750843341, 'Validation': 1.481806794802348} 5
# Training vs. Validation accuracy {'Training': 0.4367026388645172, 'Validation': 0.5187713503837585} 5
# Epoch 5:
# Accuracy train:0.4946025609970093, val:0.4778156876564026
# LOSS train 1.4228872244174664 valid 1.4159731070200603
# Training vs. Validation Loss {'Training': 1.4228872244174664, 'Validation': 1.4159731070200603} 6
# Training vs. Validation accuracy {'Training': 0.4946025609970093, 'Validation': 0.4778156876564026} 6
# Epoch 6:
# Accuracy train:0.5338567495346069, val:0.47098976373672485
# LOSS train 1.3150987166624803 valid 1.3213031788667042
# Training vs. Validation Loss {'Training': 1.3150987166624803, 'Validation': 1.3213031788667042} 7
# Training vs. Validation accuracy {'Training': 0.5338567495346069, 'Validation': 0.47098976373672485} 7
# Epoch 7:
# Accuracy train:0.5495584011077881, val:0.5665528774261475
# LOSS train 1.2078523819263165 valid 1.1715908547242482
# Training vs. Validation Loss {'Training': 1.2078523819263165, 'Validation': 1.1715908547242482} 8
# Training vs. Validation accuracy {'Training': 0.5495584011077881, 'Validation': 0.5665528774261475} 8
# Epoch 8:
# Accuracy train:0.5888125896453857, val:0.638225257396698
# LOSS train 1.063253907056955 valid 1.0276949008305867
# Training vs. Validation Loss {'Training': 1.063253907056955, 'Validation': 1.0276949008305867} 9
# Training vs. Validation accuracy {'Training': 0.5888125896453857, 'Validation': 0.638225257396698} 9
# Epoch 9:
# Accuracy train:0.6476938128471375, val:0.7815699577331543
# LOSS train 0.9408934299762433 valid 0.8773555358250936
# Training vs. Validation Loss {'Training': 0.9408934299762433, 'Validation': 0.8773555358250936} 10
# Training vs. Validation accuracy {'Training': 0.6476938128471375, 'Validation': 0.7815699577331543} 10
# Epoch 10:
# Accuracy train:0.7163886427879333, val:0.9078498482704163
# LOSS train 0.8003389170536628 valid 0.7279165064295133
# Training vs. Validation Loss {'Training': 0.8003389170536628, 'Validation': 0.7279165064295133} 11
# Training vs. Validation accuracy {'Training': 0.7163886427879333, 'Validation': 0.9078498482704163} 11
# Epoch 11:
# Accuracy train:0.7772325873374939, val:0.9488054513931274
# LOSS train 0.7156878205446097 valid 0.608113576968511
# Training vs. Validation Loss {'Training': 0.7156878205446097, 'Validation': 0.608113576968511} 12
# Training vs. Validation accuracy {'Training': 0.7772325873374939, 'Validation': 0.9488054513931274} 12
# Epoch 12:
# Accuracy train:0.8508341312408447, val:0.9863481521606445
# LOSS train 0.6089549225110275 valid 0.4901328111688296
# Training vs. Validation Loss {'Training': 0.6089549225110275, 'Validation': 0.4901328111688296} 13
# Training vs. Validation accuracy {'Training': 0.8508341312408447, 'Validation': 0.9863481521606445} 13
# Epoch 13:
# Accuracy train:0.8812561631202698, val:0.9829351305961609
# LOSS train 0.5032277359412267 valid 0.3878641265134017
# Training vs. Validation Loss {'Training': 0.5032277359412267, 'Validation': 0.3878641265134017} 14
# Training vs. Validation accuracy {'Training': 0.8812561631202698, 'Validation': 0.9829351305961609} 14
# Epoch 14:
# Accuracy train:0.897939145565033, val:0.9931740760803223
# LOSS train 0.4158509780581181 valid 0.30355009622871876
# Training vs. Validation Loss {'Training': 0.4158509780581181, 'Validation': 0.30355009622871876} 15
# Training vs. Validation accuracy {'Training': 0.897939145565033, 'Validation': 0.9931740760803223} 15
# Epoch 15:
# Accuracy train:0.9244357347488403, val:0.9931740760803223
# LOSS train 0.34189314051316333 valid 0.21954249776899815
# Training vs. Validation Loss {'Training': 0.34189314051316333, 'Validation': 0.21954249776899815} 16
# Training vs. Validation accuracy {'Training': 0.9244357347488403, 'Validation': 0.9931740760803223} 16
# Epoch 16:
# Accuracy train:0.9411187171936035, val:0.9931740760803223
# LOSS train 0.2931170635498487 valid 0.1366992136463523
# Training vs. Validation Loss {'Training': 0.2931170635498487, 'Validation': 0.1366992136463523} 17
# Training vs. Validation accuracy {'Training': 0.9411187171936035, 'Validation': 0.9931740760803223} 17
# Epoch 17:
# Accuracy train:0.9499509334564209, val:0.9931740760803223
# LOSS train 0.24640403000208047 valid 0.1073419355476896
# Training vs. Validation Loss {'Training': 0.24640403000208047, 'Validation': 0.1073419355476896} 18
# Training vs. Validation accuracy {'Training': 0.9499509334564209, 'Validation': 0.9931740760803223} 18
# Epoch 18:
# Accuracy train:0.9578017592430115, val:0.9931740760803223
# LOSS train 0.1979657789835563 valid 0.07324285937162738
# Training vs. Validation Loss {'Training': 0.1979657789835563, 'Validation': 0.07324285937162738} 19
# Training vs. Validation accuracy {'Training': 0.9578017592430115, 'Validation': 0.9931740760803223} 19
# Epoch 19:
# Accuracy train:0.9685966372489929, val:0.9931740760803223
# LOSS train 0.17175635122335875 valid 0.056156868735949196
# Training vs. Validation Loss {'Training': 0.17175635122335875, 'Validation': 0.056156868735949196} 20
# Training vs. Validation accuracy {'Training': 0.9685966372489929, 'Validation': 0.9931740760803223} 20
# Epoch 20:
# Accuracy train:0.9735034108161926, val:0.9931740760803223
# LOSS train 0.141185976135043 valid 0.04354172355184952
# Training vs. Validation Loss {'Training': 0.141185976135043, 'Validation': 0.04354172355184952} 21
# Training vs. Validation accuracy {'Training': 0.9735034108161926, 'Validation': 0.9931740760803223} 21
# Epoch 21:
# Accuracy train:0.9735034108161926, val:0.9931740760803223
# LOSS train 0.1336792862186065 valid 0.03550656601631393
# Training vs. Validation Loss {'Training': 0.1336792862186065, 'Validation': 0.03550656601631393} 22
# Training vs. Validation accuracy {'Training': 0.9735034108161926, 'Validation': 0.9931740760803223} 22
# Epoch 22:
# Accuracy train:0.9715407490730286, val:0.9931740760803223
# LOSS train 0.13233390966287026 valid 0.0340582353528589
# Training vs. Validation Loss {'Training': 0.13233390966287026, 'Validation': 0.0340582353528589} 23
# Training vs. Validation accuracy {'Training': 0.9715407490730286, 'Validation': 0.9931740760803223} 23
# Epoch 23:
# Accuracy train:0.981354296207428, val:0.9829351305961609
# LOSS train 0.1067863586716927 valid 0.041334787713518985
# Training vs. Validation Loss {'Training': 0.1067863586716927, 'Validation': 0.041334787713518985} 24
# Training vs. Validation accuracy {'Training': 0.981354296207428, 'Validation': 0.9829351305961609} 24
# Epoch 24:
# Accuracy train:0.9784101843833923, val:0.9931740760803223
# LOSS train 0.09601461715423144 valid 0.029931891496138025
# Training vs. Validation Loss {'Training': 0.09601461715423144, 'Validation': 0.029931891496138025} 25
# Training vs. Validation accuracy {'Training': 0.9784101843833923, 'Validation': 0.9931740760803223} 25
# Epoch 25:
# Accuracy train:0.9793915748596191, val:0.9931740760803223
# LOSS train 0.09027095783788425 valid 0.02709762656983609
# Training vs. Validation Loss {'Training': 0.09027095783788425, 'Validation': 0.02709762656983609} 26
# Training vs. Validation accuracy {'Training': 0.9793915748596191, 'Validation': 0.9931740760803223} 26
# Epoch 26:
# Accuracy train:0.983316957950592, val:0.9931740760803223
# LOSS train 0.07830331510362717 valid 0.026118533220142126
# Training vs. Validation Loss {'Training': 0.07830331510362717, 'Validation': 0.026118533220142126} 27
# Training vs. Validation accuracy {'Training': 0.983316957950592, 'Validation': 0.9931740760803223} 27
# Epoch 27:
# Accuracy train:0.9852796792984009, val:0.9931740760803223
# LOSS train 0.07039375581706946 valid 0.03322616347577423
# Training vs. Validation Loss {'Training': 0.07039375581706946, 'Validation': 0.03322616347577423} 28
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9931740760803223} 28
# Epoch 28:
# Accuracy train:0.9803729057312012, val:0.9931740760803223
# LOSS train 0.09373897306907636 valid 0.027366520026892733
# Training vs. Validation Loss {'Training': 0.09373897306907636, 'Validation': 0.027366520026892733} 29
# Training vs. Validation accuracy {'Training': 0.9803729057312012, 'Validation': 0.9931740760803223} 29
# Epoch 29:
# Accuracy train:0.983316957950592, val:0.9931740760803223
# LOSS train 0.06944339786871122 valid 0.01961107644213674
# Training vs. Validation Loss {'Training': 0.06944339786871122, 'Validation': 0.01961107644213674} 30
# Training vs. Validation accuracy {'Training': 0.983316957950592, 'Validation': 0.9931740760803223} 30
# Epoch 30:
# Accuracy train:0.983316957950592, val:0.9931740760803223
# LOSS train 0.06464026137613334 valid 0.026448395762902994
# Training vs. Validation Loss {'Training': 0.06464026137613334, 'Validation': 0.026448395762902994} 31
# Training vs. Validation accuracy {'Training': 0.983316957950592, 'Validation': 0.9931740760803223} 31
# Epoch 31:
# Accuracy train:0.9774288535118103, val:0.9931740760803223
# LOSS train 0.06828608510729212 valid 0.03280570345668821
# Training vs. Validation Loss {'Training': 0.06828608510729212, 'Validation': 0.03280570345668821} 32
# Training vs. Validation accuracy {'Training': 0.9774288535118103, 'Validation': 0.9931740760803223} 32
# Epoch 32:
# Accuracy train:0.9872424006462097, val:0.9931740760803223
# LOSS train 0.06192686057721193 valid 0.026575057342900738
# Training vs. Validation Loss {'Training': 0.06192686057721193, 'Validation': 0.026575057342900738} 33
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9931740760803223} 33
# Epoch 33:
# Accuracy train:0.9803729057312012, val:0.9931740760803223
# LOSS train 0.054802958674442306 valid 0.02043190394275977
# Training vs. Validation Loss {'Training': 0.054802958674442306, 'Validation': 0.02043190394275977} 34
# Training vs. Validation accuracy {'Training': 0.9803729057312012, 'Validation': 0.9931740760803223} 34
# Epoch 34:
# Accuracy train:0.9842983484268188, val:0.9829351305961609
# LOSS train 0.07502871959541853 valid 0.03429238535682089
# Training vs. Validation Loss {'Training': 0.07502871959541853, 'Validation': 0.03429238535682089} 35
# Training vs. Validation accuracy {'Training': 0.9842983484268188, 'Validation': 0.9829351305961609} 35
# Epoch 35:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.05666686784332761 valid 0.027269452150600653
# Training vs. Validation Loss {'Training': 0.05666686784332761, 'Validation': 0.027269452150600653} 36
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 36
# Epoch 36:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.05098963188580596 valid 0.028313273899887765
# Training vs. Validation Loss {'Training': 0.05098963188580596, 'Validation': 0.028313273899887765} 37
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 37
# Epoch 37:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.06753044027405289 valid 0.0250584480939627
# Training vs. Validation Loss {'Training': 0.06753044027405289, 'Validation': 0.0250584480939627} 38
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 38
# Epoch 38:
# Accuracy train:0.9842983484268188, val:0.9931740760803223
# LOSS train 0.06911381063624643 valid 0.025012886498492055
# Training vs. Validation Loss {'Training': 0.06911381063624643, 'Validation': 0.025012886498492055} 39
# Training vs. Validation accuracy {'Training': 0.9842983484268188, 'Validation': 0.9931740760803223} 39
# Epoch 39:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.05076910741627216 valid 0.023630257476421928
# Training vs. Validation Loss {'Training': 0.05076910741627216, 'Validation': 0.023630257476421928} 40
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 40
# Epoch 40:
# Accuracy train:0.9872424006462097, val:0.9931740760803223
# LOSS train 0.04210053767579106 valid 0.029181596568378154
# Training vs. Validation Loss {'Training': 0.04210053767579106, 'Validation': 0.029181596568378154} 41
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9931740760803223} 41
# Epoch 41:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.03747833609724274 valid 0.017247960618988145
# Training vs. Validation Loss {'Training': 0.03747833609724274, 'Validation': 0.017247960618988145} 42
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 42
# Epoch 42:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.04434563121042 valid 0.019941989910876146
# Training vs. Validation Loss {'Training': 0.04434563121042, 'Validation': 0.019941989910876146} 43
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 43
# Epoch 43:
# Accuracy train:0.9911677837371826, val:0.9863481521606445
# LOSS train 0.05795550690247463 valid 0.02714591992116766
# Training vs. Validation Loss {'Training': 0.05795550690247463, 'Validation': 0.02714591992116766} 44
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9863481521606445} 44
# Epoch 44:
# Accuracy train:0.9852796792984009, val:0.9931740760803223
# LOSS train 0.04630603074418524 valid 0.0301833793194722
# Training vs. Validation Loss {'Training': 0.04630603074418524, 'Validation': 0.0301833793194722} 45
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9931740760803223} 45
# Epoch 45:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.04508095041203957 valid 0.02620839553856058
# Training vs. Validation Loss {'Training': 0.04508095041203957, 'Validation': 0.02620839553856058} 46
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 46
# Epoch 46:
# Accuracy train:0.9872424006462097, val:0.9931740760803223
# LOSS train 0.04800990370746989 valid 0.029153411647106015
# Training vs. Validation Loss {'Training': 0.04800990370746989, 'Validation': 0.029153411647106015} 47
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9931740760803223} 47
# Epoch 47:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.03664963176617256 valid 0.026652074858247943
# Training vs. Validation Loss {'Training': 0.03664963176617256, 'Validation': 0.026652074858247943} 48
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 48
# Epoch 48:
# Accuracy train:0.9872424006462097, val:0.9931740760803223
# LOSS train 0.04170892308824337 valid 0.024472347023523373
# Training vs. Validation Loss {'Training': 0.04170892308824337, 'Validation': 0.024472347023523373} 49
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9931740760803223} 49
# Epoch 49:
# Accuracy train:0.9852796792984009, val:0.9931740760803223
# LOSS train 0.045286083074573144 valid 0.01736515753934024
# Training vs. Validation Loss {'Training': 0.045286083074573144, 'Validation': 0.01736515753934024} 50
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9931740760803223} 50
# Epoch 50:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.04106190583507459 valid 0.023874325961211678
# Training vs. Validation Loss {'Training': 0.04106190583507459, 'Validation': 0.023874325961211678} 51
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 51
# Epoch 51:
# Accuracy train:0.9862610697746277, val:0.9931740760803223
# LOSS train 0.047301474815377824 valid 0.020073989705451822
# Training vs. Validation Loss {'Training': 0.047301474815377824, 'Validation': 0.020073989705451822} 52
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9931740760803223} 52
# Epoch 52:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.038243914873769075 valid 0.021274945469788992
# Training vs. Validation Loss {'Training': 0.038243914873769075, 'Validation': 0.021274945469788992} 53
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 53
# Epoch 53:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.049389732016537055 valid 0.019708776547001133
# Training vs. Validation Loss {'Training': 0.049389732016537055, 'Validation': 0.019708776547001133} 54
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 54
# Epoch 54:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.051516159974898286 valid 0.02374775824137032
# Training vs. Validation Loss {'Training': 0.051516159974898286, 'Validation': 0.02374775824137032} 55
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 55
# Epoch 55:
# Accuracy train:0.9872424006462097, val:0.9931740760803223
# LOSS train 0.03134366361281046 valid 0.023127920290789916
# Training vs. Validation Loss {'Training': 0.03134366361281046, 'Validation': 0.023127920290789916} 56
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9931740760803223} 56
# Epoch 56:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.03360105345312219 valid 0.025333576095969573
# Training vs. Validation Loss {'Training': 0.03360105345312219, 'Validation': 0.025333576095969573} 57
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 57
# Epoch 57:
# Accuracy train:0.9852796792984009, val:0.9931740760803223
# LOSS train 0.04988626336965423 valid 0.024266462359870882
# Training vs. Validation Loss {'Training': 0.04988626336965423, 'Validation': 0.024266462359870882} 58
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9931740760803223} 58
# Epoch 58:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.027269496474988185 valid 0.020536281799953333
# Training vs. Validation Loss {'Training': 0.027269496474988185, 'Validation': 0.020536281799953333} 59
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 59
# Epoch 59:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.028904659897447206 valid 0.015112800428141782
# Training vs. Validation Loss {'Training': 0.028904659897447206, 'Validation': 0.015112800428141782} 60
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 60
# Epoch 60:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.03562107319549586 valid 0.013651841525188502
# Training vs. Validation Loss {'Training': 0.03562107319549586, 'Validation': 0.013651841525188502} 61
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 61
# Epoch 61:
# Accuracy train:0.9862610697746277, val:0.9931740760803223
# LOSS train 0.041114971811811514 valid 0.01872062550910414
# Training vs. Validation Loss {'Training': 0.041114971811811514, 'Validation': 0.01872062550910414} 62
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9931740760803223} 62
# Epoch 62:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.026460400343729325 valid 0.01772643595207531
# Training vs. Validation Loss {'Training': 0.026460400343729325, 'Validation': 0.01772643595207531} 63
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9965870380401611} 63
# Epoch 63:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.03515081395968222 valid 0.02040651229708601
# Training vs. Validation Loss {'Training': 0.03515081395968222, 'Validation': 0.02040651229708601} 64
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 64
# Epoch 64:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.028033895704608697 valid 0.019836687784694124
# Training vs. Validation Loss {'Training': 0.028033895704608697, 'Validation': 0.019836687784694124} 65
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 65
# Epoch 65:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.03681491372676996 valid 0.020717167486054677
# Training vs. Validation Loss {'Training': 0.03681491372676996, 'Validation': 0.020717167486054677} 66
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 66
# Epoch 66:
# Accuracy train:0.983316957950592, val:0.9931740760803223
# LOSS train 0.026839059956658345 valid 0.01589601655973638
# Training vs. Validation Loss {'Training': 0.026839059956658345, 'Validation': 0.01589601655973638} 67
# Training vs. Validation accuracy {'Training': 0.983316957950592, 'Validation': 0.9931740760803223} 67
# Epoch 67:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.043106947192707315 valid 0.014093760847799786
# Training vs. Validation Loss {'Training': 0.043106947192707315, 'Validation': 0.014093760847799786} 68
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 68
# Epoch 68:
# Accuracy train:0.9911677837371826, val:0.9897611141204834
# LOSS train 0.03913622903816689 valid 0.02068588932646283
# Training vs. Validation Loss {'Training': 0.03913622903816689, 'Validation': 0.02068588932646283} 69
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9897611141204834} 69
# Epoch 69:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.04472483358739947 valid 0.021151871496385866
# Training vs. Validation Loss {'Training': 0.04472483358739947, 'Validation': 0.021151871496385866} 70
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 70
# Epoch 70:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.041324566709450804 valid 0.025168684974232747
# Training vs. Validation Loss {'Training': 0.041324566709450804, 'Validation': 0.025168684974232747} 71
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 71
# Epoch 71:
# Accuracy train:0.983316957950592, val:0.9897611141204834
# LOSS train 0.03601337018279502 valid 0.01730055043064264
# Training vs. Validation Loss {'Training': 0.03601337018279502, 'Validation': 0.01730055043064264} 72
# Training vs. Validation accuracy {'Training': 0.983316957950592, 'Validation': 0.9897611141204834} 72
# Epoch 72:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.032349647036216296 valid 0.019220783088106447
# Training vs. Validation Loss {'Training': 0.032349647036216296, 'Validation': 0.019220783088106447} 73
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 73
# Epoch 73:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.03202727869994795 valid 0.023199327550476784
# Training vs. Validation Loss {'Training': 0.03202727869994795, 'Validation': 0.023199327550476784} 74
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 74
# Epoch 74:
# Accuracy train:0.9901864528656006, val:0.9897611141204834
# LOSS train 0.030259147649093602 valid 0.02168372500273108
# Training vs. Validation Loss {'Training': 0.030259147649093602, 'Validation': 0.02168372500273108} 75
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9897611141204834} 75
# Epoch 75:
# Accuracy train:0.9901864528656006, val:0.9897611141204834
# LOSS train 0.03405769730810649 valid 0.018481823424887505
# Training vs. Validation Loss {'Training': 0.03405769730810649, 'Validation': 0.018481823424887505} 76
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9897611141204834} 76
# Epoch 76:
# Accuracy train:0.9911677837371826, val:0.9897611141204834
# LOSS train 0.030674447654746473 valid 0.020299288149241573
# Training vs. Validation Loss {'Training': 0.030674447654746473, 'Validation': 0.020299288149241573} 77
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9897611141204834} 77
# Epoch 77:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.02607852391576251 valid 0.024390901081612053
# Training vs. Validation Loss {'Training': 0.02607852391576251, 'Validation': 0.024390901081612053} 78
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 78
# Epoch 78:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.023876649846967597 valid 0.017143545668811083
# Training vs. Validation Loss {'Training': 0.023876649846967597, 'Validation': 0.017143545668811083} 79
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 79
# Epoch 79:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.02909536507482139 valid 0.026009554559777825
# Training vs. Validation Loss {'Training': 0.02909536507482139, 'Validation': 0.026009554559777825} 80
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 80
# Epoch 80:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.020047619679154687 valid 0.022654166114913703
# Training vs. Validation Loss {'Training': 0.020047619679154687, 'Validation': 0.022654166114913703} 81
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 81
# Epoch 81:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.03426076168230233 valid 0.023083375794840322
# Training vs. Validation Loss {'Training': 0.03426076168230233, 'Validation': 0.023083375794840322} 82
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 82
# Epoch 82:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.030340303443014048 valid 0.021384955399942857
# Training vs. Validation Loss {'Training': 0.030340303443014048, 'Validation': 0.021384955399942857} 83
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 83
# Epoch 83:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.021185314618588354 valid 0.02166018870239365
# Training vs. Validation Loss {'Training': 0.021185314618588354, 'Validation': 0.02166018870239365} 84
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 84
# Epoch 84:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.023151144909206778 valid 0.028974759372886183
# Training vs. Validation Loss {'Training': 0.023151144909206778, 'Validation': 0.028974759372886183} 85
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 85
# Epoch 85:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.022126145797441356 valid 0.021597147561995673
# Training vs. Validation Loss {'Training': 0.022126145797441356, 'Validation': 0.021597147561995673} 86
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 86
# Epoch 86:
# Accuracy train:0.9941118955612183, val:0.9897611141204834
# LOSS train 0.024058013769368138 valid 0.01767559582386487
# Training vs. Validation Loss {'Training': 0.024058013769368138, 'Validation': 0.01767559582386487} 87
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9897611141204834} 87
# Epoch 87:
# Accuracy train:0.9950932264328003, val:0.9897611141204834
# LOSS train 0.01862603182402941 valid 0.020557488394426098
# Training vs. Validation Loss {'Training': 0.01862603182402941, 'Validation': 0.020557488394426098} 88
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9897611141204834} 88
# Epoch 88:
# Accuracy train:0.9921491742134094, val:0.9897611141204834
# LOSS train 0.02294374400158771 valid 0.021841968844588184
# Training vs. Validation Loss {'Training': 0.02294374400158771, 'Validation': 0.021841968844588184} 89
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9897611141204834} 89
# Epoch 89:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.024816223626168303 valid 0.024718730205847805
# Training vs. Validation Loss {'Training': 0.024816223626168303, 'Validation': 0.024718730205847805} 90
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 90
# Epoch 90:
# Accuracy train:0.9921491742134094, val:0.9897611141204834
# LOSS train 0.048537994611811325 valid 0.018614517823114813
# Training vs. Validation Loss {'Training': 0.048537994611811325, 'Validation': 0.018614517823114813} 91
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9897611141204834} 91
# Epoch 91:
# Accuracy train:0.9950932264328003, val:0.9897611141204834
# LOSS train 0.028421088583015192 valid 0.021278716872113062
# Training vs. Validation Loss {'Training': 0.028421088583015192, 'Validation': 0.021278716872113062} 92
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9897611141204834} 92
# Epoch 92:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.026164468525586508 valid 0.02539538300506668
# Training vs. Validation Loss {'Training': 0.026164468525586508, 'Validation': 0.02539538300506668} 93
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 93
# Epoch 93:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.023151202933289684 valid 0.021821035499215213
# Training vs. Validation Loss {'Training': 0.023151202933289684, 'Validation': 0.021821035499215213} 94
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 94
# Epoch 94:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.026790173527283166 valid 0.01941362010397067
# Training vs. Validation Loss {'Training': 0.026790173527283166, 'Validation': 0.01941362010397067} 95
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 95
# Epoch 95:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.03343195532663511 valid 0.024323829933602308
# Training vs. Validation Loss {'Training': 0.03343195532663511, 'Validation': 0.024323829933602308} 96
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 96
# Epoch 96:
# Accuracy train:0.9901864528656006, val:0.9897611141204834
# LOSS train 0.029302467480122756 valid 0.023307565608225406
# Training vs. Validation Loss {'Training': 0.029302467480122756, 'Validation': 0.023307565608225406} 97
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9897611141204834} 97
# Epoch 97:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.031106458032109704 valid 0.024320045894758852
# Training vs. Validation Loss {'Training': 0.031106458032109704, 'Validation': 0.024320045894758852} 98
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 98
# Epoch 98:
# Accuracy train:0.9921491742134094, val:0.9897611141204834
# LOSS train 0.03015175642660604 valid 0.023219493136006502
# Training vs. Validation Loss {'Training': 0.03015175642660604, 'Validation': 0.023219493136006502} 99
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9897611141204834} 99
# Epoch 99:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.018852812667878773 valid 0.025328824775366836
# Training vs. Validation Loss {'Training': 0.018852812667878773, 'Validation': 0.025328824775366836} 100
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 100
# Epoch 100:
# Accuracy train:0.9921491742134094, val:0.9863481521606445
# LOSS train 0.024293667195776764 valid 0.029941083378380046
# Training vs. Validation Loss {'Training': 0.024293667195776764, 'Validation': 0.029941083378380046} 101
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9863481521606445} 101
# Epoch 101:
# Accuracy train:0.9950932264328003, val:0.9897611141204834
# LOSS train 0.015052912044876184 valid 0.02919670423466414
# Training vs. Validation Loss {'Training': 0.015052912044876184, 'Validation': 0.02919670423466414} 102
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9897611141204834} 102
# Epoch 102:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.02899127120214801 valid 0.03070093333082961
# Training vs. Validation Loss {'Training': 0.02899127120214801, 'Validation': 0.03070093333082961} 103
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 103
# Epoch 103:
# Accuracy train:0.9980372786521912, val:0.9897611141204834
# LOSS train 0.019157853201389886 valid 0.03204319268045689
# Training vs. Validation Loss {'Training': 0.019157853201389886, 'Validation': 0.03204319268045689} 104
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9897611141204834} 104
# Epoch 104:
# Accuracy train:0.9921491742134094, val:0.9897611141204834
# LOSS train 0.019781743668807812 valid 0.031969660309944935
# Training vs. Validation Loss {'Training': 0.019781743668807812, 'Validation': 0.031969660309944935} 105
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9897611141204834} 105
# Epoch 105:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.023835397088147987 valid 0.030319021111059403
# Training vs. Validation Loss {'Training': 0.023835397088147987, 'Validation': 0.030319021111059403} 106
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 106
# Epoch 106:
# Accuracy train:0.9960745573043823, val:0.9897611141204834
# LOSS train 0.015149072262619693 valid 0.031186179583983176
# Training vs. Validation Loss {'Training': 0.015149072262619693, 'Validation': 0.031186179583983176} 107
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9897611141204834} 107
# Epoch 107:
# Accuracy train:0.9950932264328003, val:0.9897611141204834
# LOSS train 0.016432230331702158 valid 0.027510840061381714
# Training vs. Validation Loss {'Training': 0.016432230331702158, 'Validation': 0.027510840061381714} 108
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9897611141204834} 108
# Epoch 108:
# Accuracy train:0.9941118955612183, val:0.9897611141204834
# LOSS train 0.022630041968883373 valid 0.03158998617304102
# Training vs. Validation Loss {'Training': 0.022630041968883373, 'Validation': 0.03158998617304102} 109
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9897611141204834} 109
# Epoch 109:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.010748962936654257 valid 0.02578141959918412
# Training vs. Validation Loss {'Training': 0.010748962936654257, 'Validation': 0.02578141959918412} 110
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 110
# Epoch 110:
# Accuracy train:0.9960745573043823, val:0.9863481521606445
# LOSS train 0.034918886403409906 valid 0.030708199689996718
# Training vs. Validation Loss {'Training': 0.034918886403409906, 'Validation': 0.030708199689996718} 111
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9863481521606445} 111
# Epoch 111:
# Accuracy train:0.9941118955612183, val:0.9897611141204834
# LOSS train 0.020267979470260728 valid 0.03125595888362417
# Training vs. Validation Loss {'Training': 0.020267979470260728, 'Validation': 0.03125595888362417} 112
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9897611141204834} 112
# Epoch 112:
# Accuracy train:0.9960745573043823, val:0.9897611141204834
# LOSS train 0.01564799221859385 valid 0.03170657701239558
# Training vs. Validation Loss {'Training': 0.01564799221859385, 'Validation': 0.03170657701239558} 113
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9897611141204834} 113
# Epoch 113:
# Accuracy train:0.9980372786521912, val:0.9897611141204834
# LOSS train 0.015651269524823874 valid 0.03314523590230086
# Training vs. Validation Loss {'Training': 0.015651269524823874, 'Validation': 0.03314523590230086} 114
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9897611141204834} 114
# Epoch 114:
# Accuracy train:0.9941118955612183, val:0.9897611141204834
# LOSS train 0.025332067085680768 valid 0.027556220234155642
# Training vs. Validation Loss {'Training': 0.025332067085680768, 'Validation': 0.027556220234155642} 115
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9897611141204834} 115
# Epoch 115:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.02107427120566941 valid 0.031476599627827305
# Training vs. Validation Loss {'Training': 0.02107427120566941, 'Validation': 0.031476599627827305} 116
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 116
# Epoch 116:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.03075037286348211 valid 0.027222208652214402
# Training vs. Validation Loss {'Training': 0.03075037286348211, 'Validation': 0.027222208652214402} 117
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 117
# Epoch 117:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.02886592976238507 valid 0.031626290323326124
# Training vs. Validation Loss {'Training': 0.02886592976238507, 'Validation': 0.031626290323326124} 118
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 118
# Epoch 118:
# Accuracy train:0.9970559477806091, val:0.9931740760803223
# LOSS train 0.016370313114468724 valid 0.031287507532927826
# Training vs. Validation Loss {'Training': 0.016370313114468724, 'Validation': 0.031287507532927826} 119
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9931740760803223} 119
# Epoch 119:
# Accuracy train:0.9960745573043823, val:0.9897611141204834
# LOSS train 0.015785921678448524 valid 0.03314414865737566
# Training vs. Validation Loss {'Training': 0.015785921678448524, 'Validation': 0.03314414865737566} 120
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9897611141204834} 120
# Epoch 120:
# Accuracy train:0.9960745573043823, val:0.9897611141204834
# LOSS train 0.015213128436768714 valid 0.031364384580446845
# Training vs. Validation Loss {'Training': 0.015213128436768714, 'Validation': 0.031364384580446845} 121
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9897611141204834} 121
# Stoping at epoch 120,minimum: 0.013651841525188502
# Epoch 121:
# Accuracy train:0.9941118955612183, val:0.9863481521606445
# LOSS train 0.02512935738867292 valid 0.03406193873147837
# Training vs. Validation Loss {'Training': 0.02512935738867292, 'Validation': 0.03406193873147837} 122
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9863481521606445} 122
# Stoping at epoch 121,minimum: 0.013651841525188502
# Epoch 122:
# Accuracy train:0.9911677837371826, val:0.9897611141204834
# LOSS train 0.019433862558798864 valid 0.04754767339740814
# Training vs. Validation Loss {'Training': 0.019433862558798864, 'Validation': 0.04754767339740814} 123
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9897611141204834} 123
# Stoping at epoch 122,minimum: 0.013651841525188502
# Epoch 123:
# Accuracy train:0.9960745573043823, val:0.9897611141204834
# LOSS train 0.01545043492044967 valid 0.03530311157074569
# Training vs. Validation Loss {'Training': 0.01545043492044967, 'Validation': 0.03530311157074569} 124
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9897611141204834} 124
# Stoping at epoch 123,minimum: 0.013651841525188502
# Epoch 124:
# Accuracy train:0.9941118955612183, val:0.9897611141204834
# LOSS train 0.020790177672796954 valid 0.033419903014277
# Training vs. Validation Loss {'Training': 0.020790177672796954, 'Validation': 0.033419903014277} 125
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9897611141204834} 125
# Stoping at epoch 124,minimum: 0.013651841525188502
# Epoch 125:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.02172522484145772 valid 0.03314255877181912
# Training vs. Validation Loss {'Training': 0.02172522484145772, 'Validation': 0.03314255877181912} 126
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 126
# Stoping at epoch 125,minimum: 0.013651841525188502
# Epoch 126:
# Accuracy train:0.9911677837371826, val:0.9897611141204834
# LOSS train 0.026356069523339663 valid 0.034638039378942644
# Training vs. Validation Loss {'Training': 0.026356069523339663, 'Validation': 0.034638039378942644} 127
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9897611141204834} 127
# Stoping at epoch 126,minimum: 0.013651841525188502
# Epoch 127:
# Accuracy train:0.9921491742134094, val:0.9897611141204834
# LOSS train 0.016947186614673298 valid 0.027622904594314452
# Training vs. Validation Loss {'Training': 0.016947186614673298, 'Validation': 0.027622904594314452} 128
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9897611141204834} 128
# Stoping at epoch 127,minimum: 0.013651841525188502
# Epoch 128:
# Accuracy train:0.9921491742134094, val:0.9897611141204834
# LOSS train 0.014990510063048882 valid 0.03648460545870572
# Training vs. Validation Loss {'Training': 0.014990510063048882, 'Validation': 0.03648460545870572} 129
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9897611141204834} 129
# Stoping at epoch 128,minimum: 0.013651841525188502
# Epoch 129:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.02204631420541913 valid 0.05044546333654883
# Training vs. Validation Loss {'Training': 0.02204631420541913, 'Validation': 0.05044546333654883} 130
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 130
# Stoping at epoch 129,minimum: 0.013651841525188502
# Epoch 130:
# Accuracy train:0.9980372786521912, val:0.9897611141204834
# LOSS train 0.018323256546864286 valid 0.047797715991900226
# Training vs. Validation Loss {'Training': 0.018323256546864286, 'Validation': 0.047797715991900226} 131
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9897611141204834} 131
# Stoping at epoch 130,minimum: 0.013651841525188502
# Epoch 131:
# Accuracy train:0.9941118955612183, val:0.9863481521606445
# LOSS train 0.01388567553098815 valid 0.04117472621500914
# Training vs. Validation Loss {'Training': 0.01388567553098815, 'Validation': 0.04117472621500914} 132
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9863481521606445} 132
# Stoping at epoch 131,minimum: 0.013651841525188502
# Epoch 132:
# Accuracy train:0.9970559477806091, val:0.9863481521606445
# LOSS train 0.022373215698350508 valid 0.043615164481347314
# Training vs. Validation Loss {'Training': 0.022373215698350508, 'Validation': 0.043615164481347314} 133
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9863481521606445} 133
# Stoping at epoch 132,minimum: 0.013651841525188502
# Epoch 133:
# Accuracy train:0.9950932264328003, val:0.9863481521606445
# LOSS train 0.017730741085520443 valid 0.0426846920320069
# Training vs. Validation Loss {'Training': 0.017730741085520443, 'Validation': 0.0426846920320069} 134
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9863481521606445} 134
# Stoping at epoch 133,minimum: 0.013651841525188502
# Epoch 134:
# Accuracy train:0.9941118955612183, val:0.9897611141204834
# LOSS train 0.014859842329035299 valid 0.03474848230266995
# Training vs. Validation Loss {'Training': 0.014859842329035299, 'Validation': 0.03474848230266995} 135
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9897611141204834} 135
# Stoping at epoch 134,minimum: 0.013651841525188502
# Epoch 135:
# Accuracy train:0.9960745573043823, val:0.9863481521606445
# LOSS train 0.03481441690998439 valid 0.03707317863067298
# Training vs. Validation Loss {'Training': 0.03481441690998439, 'Validation': 0.03707317863067298} 136
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9863481521606445} 136
# Stoping at epoch 135,minimum: 0.013651841525188502
# Epoch 136:
# Accuracy train:0.9941118955612183, val:0.9829351305961609
# LOSS train 0.012170321460311802 valid 0.04474100273311876
# Training vs. Validation Loss {'Training': 0.012170321460311802, 'Validation': 0.04474100273311876} 137
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9829351305961609} 137
# Stoping at epoch 136,minimum: 0.013651841525188502
# Epoch 137:
# Accuracy train:0.9960745573043823, val:0.9897611141204834
# LOSS train 0.014178030273447243 valid 0.03513055166012672
# Training vs. Validation Loss {'Training': 0.014178030273447243, 'Validation': 0.03513055166012672} 138
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9897611141204834} 138
# Stoping at epoch 137,minimum: 0.013651841525188502
# Epoch 138:
# Accuracy train:0.9960745573043823, val:0.9897611141204834
# LOSS train 0.023859546833241787 valid 0.03287112087049119
# Training vs. Validation Loss {'Training': 0.023859546833241787, 'Validation': 0.03287112087049119} 139
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9897611141204834} 139
# Stoping at epoch 138,minimum: 0.013651841525188502
# Epoch 139:
# Accuracy train:0.9960745573043823, val:0.9863481521606445
# LOSS train 0.029841964947991073 valid 0.047332231291477456
# Training vs. Validation Loss {'Training': 0.029841964947991073, 'Validation': 0.047332231291477456} 140
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9863481521606445} 140
# Stoping at epoch 139,minimum: 0.013651841525188502
# Epoch 140:
# Accuracy train:0.9970559477806091, val:0.9897611141204834
# LOSS train 0.011008345795114739 valid 0.030912331390965164
# Training vs. Validation Loss {'Training': 0.011008345795114739, 'Validation': 0.030912331390965164} 141
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9897611141204834} 141
# Stoping at epoch 140,minimum: 0.013651841525188502
# Epoch 141:
# Accuracy train:0.9970559477806091, val:0.9897611141204834
# LOSS train 0.01043991063712523 valid 0.0295088655597624
# ...
# Stoping at epoch 257,minimum: 0.013651841525188502
# Epoch 258:
# Accuracy train:0.999018669128418, val:0.9897611141204834
# LOSS train 0.007357406612824819 valid 0.055621108241841334
# Training vs. Validation Loss {'Training': 0.007357406612824819, 'Validation': 0.055621108241841334} 259
# Training vs. Validation accuracy {'Training': 0.999018669128418, 'Validation': 0.9897611141204834} 259
# Stoping at epoch 258,minimum: 0.013651841525188502
# Epoch 259:
# Accuracy train:0.9980372786521912, val:0.9863481521606445
# LOSS train 0.006164558324459135 valid 0.0574007491917324
# Training vs. Validation Loss {'Training': 0.006164558324459135, 'Validation': 0.0574007491917324} 260
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9863481521606445} 260
# Stoping at epoch 259,minimum: 0.013651841525188502
# Epoch 260:
# Accuracy train:0.9960745573043823, val:0.9897611141204834
# LOSS train 0.0054149736987220915 valid 0.05512960546717771
# Training vs. Validation Loss {'Training': 0.0054149736987220915, 'Validation': 0.05512960546717771} 261
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9897611141204834} 261
# Stoping at epoch 260,minimum: 0.013651841525188502
# Epoch 261:
# Accuracy train:0.9980372786521912, val:0.9863481521606445
# LOSS train 0.008426876807509242 valid 0.05665042716612426
# Training vs. Validation Loss {'Training': 0.008426876807509242, 'Validation': 0.05665042716612426} 262
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9863481521606445} 262
# Stoping at epoch 261,minimum: 0.013651841525188502
# Epoch 262:
# Accuracy train:0.999018669128418, val:0.9863481521606445
# LOSS train 0.009652762859611986 valid 0.05734507514758377
# Training vs. Validation Loss {'Training': 0.009652762859611986, 'Validation': 0.05734507514758377} 263
# Training vs. Validation accuracy {'Training': 0.999018669128418, 'Validation': 0.9863481521606445} 263
# Stoping at epoch 262,minimum: 0.013651841525188502
# Epoch 263:
# Accuracy train:0.9970559477806091, val:0.9863481521606445
# LOSS train 0.01430302352617638 valid 0.055307400680514984
# Training vs. Validation Loss {'Training': 0.01430302352617638, 'Validation': 0.055307400680514984} 264
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9863481521606445} 264
# Stoping at epoch 263,minimum: 0.013651841525188502
# Epoch 264:
# Accuracy train:0.9970559477806091, val:0.9829351305961609
# LOSS train 0.015483789726903733 valid 0.08227749970212983
# Training vs. Validation Loss {'Training': 0.015483789726903733, 'Validation': 0.08227749970212983} 265
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9829351305961609} 265
# Stoping at epoch 264,minimum: 0.013651841525188502
# Epoch 265:
# Accuracy train:0.9970559477806091, val:0.9863481521606445
# LOSS train 0.005564861522893457 valid 0.06203246316974642
# Training vs. Validation Loss {'Training': 0.005564861522893457, 'Validation': 0.06203246316974642} 266
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9863481521606445} 266
# Stoping at epoch 265,minimum: 0.013651841525188502
# Epoch 266:
# Accuracy train:0.9970559477806091, val:0.9829351305961609
# LOSS train 0.0074427476675527245 valid 0.05968145627498522
# Training vs. Validation Loss {'Training': 0.0074427476675527245, 'Validation': 0.05968145627498522} 267
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9829351305961609} 267
# Stoping at epoch 266,minimum: 0.013651841525188502
# Epoch 267:
# Accuracy train:0.9960745573043823, val:0.9829351305961609
# LOSS train 0.010766125504372982 valid 0.061892141846322225
# Training vs. Validation Loss {'Training': 0.010766125504372982, 'Validation': 0.061892141846322225} 268
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9829351305961609} 268
# Stoping at epoch 267,minimum: 0.013651841525188502
# Epoch 268:
# Accuracy train:0.9970559477806091, val:0.979522168636322
# LOSS train 0.003922677292184045 valid 0.06635749836037459
# Training vs. Validation Loss {'Training': 0.003922677292184045, 'Validation': 0.06635749836037459} 269
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.979522168636322} 269
# Stoping at epoch 268,minimum: 0.013651841525188502
# Epoch 269:
# Accuracy train:0.9980372786521912, val:0.9897611141204834
# LOSS train 0.016318778908148836 valid 0.05275577574549343
# Training vs. Validation Loss {'Training': 0.016318778908148836, 'Validation': 0.05275577574549343} 270
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9897611141204834} 270
# Stoping at epoch 269,minimum: 0.013651841525188502
# Epoch 270:
# Accuracy train:0.9960745573043823, val:0.9863481521606445
# LOSS train 0.007023226000735751 valid 0.06408789278423536
# Training vs. Validation Loss {'Training': 0.007023226000735751, 'Validation': 0.06408789278423536} 271
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9863481521606445} 271
# Stoping at epoch 270,minimum: 0.013651841525188502
# Epoch 271:
# Accuracy train:0.9931305050849915, val:0.9863481521606445
# LOSS train 0.018311101487667587 valid 0.06248768034590587
# Training vs. Validation Loss {'Training': 0.018311101487667587, 'Validation': 0.06248768034590587} 272
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9863481521606445} 272
# Stoping at epoch 271,minimum: 0.013651841525188502
# Epoch 272:
# Accuracy train:0.9970559477806091, val:0.9863481521606445
# LOSS train 0.02234087837104408 valid 0.05994471936893878
# Training vs. Validation Loss {'Training': 0.02234087837104408, 'Validation': 0.05994471936893878} 273
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9863481521606445} 273
# Stoping at epoch 272,minimum: 0.013651841525188502
# Epoch 273:
# Accuracy train:1.0, val:0.9863481521606445
# LOSS train 0.005250026616872324 valid 0.05306559240998313
# Training vs. Validation Loss {'Training': 0.005250026616872324, 'Validation': 0.05306559240998313} 274
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9863481521606445} 274
# Stoping at epoch 273,minimum: 0.013651841525188502
# Epoch 274:
# Accuracy train:0.999018669128418, val:0.9829351305961609
# LOSS train 0.0022996900269600493 valid 0.06722200083919327
# Training vs. Validation Loss {'Training': 0.0022996900269600493, 'Validation': 0.06722200083919327} 275
# Training vs. Validation accuracy {'Training': 0.999018669128418, 'Validation': 0.9829351305961609} 275
# Stoping at epoch 274,minimum: 0.013651841525188502
# Epoch 275:
# Accuracy train:1.0, val:0.9863481521606445
# LOSS train 0.002352357803409597 valid 0.0591999349783879
# Training vs. Validation Loss {'Training': 0.002352357803409597, 'Validation': 0.0591999349783879} 276
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9863481521606445} 276
# Stoping at epoch 275,minimum: 0.013651841525188502
# Epoch 276:
# Accuracy train:0.9970559477806091, val:0.9897611141204834
# LOSS train 0.002681369489996891 valid 0.05808372856599031
# Training vs. Validation Loss {'Training': 0.002681369489996891, 'Validation': 0.05808372856599031} 277
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9897611141204834} 277
# Stoping at epoch 276,minimum: 0.013651841525188502
# Epoch 277:
# Accuracy train:0.999018669128418, val:0.9897611141204834
# LOSS train 0.005102217788170002 valid 0.05925595625809935
# Training vs. Validation Loss {'Training': 0.005102217788170002, 'Validation': 0.05925595625809935} 278
# Training vs. Validation accuracy {'Training': 0.999018669128418, 'Validation': 0.9897611141204834} 278
# Stoping at epoch 277,minimum: 0.013651841525188502
# Epoch 278:
# Accuracy train:1.0, val:0.9897611141204834
# LOSS train 0.0025141048533371827 valid 0.05457061990967297
# Training vs. Validation Loss {'Training': 0.0025141048533371827, 'Validation': 0.05457061990967297} 279
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9897611141204834} 279
# Stoping at epoch 278,minimum: 0.013651841525188502
# Epoch 279:
# Accuracy train:0.999018669128418, val:0.9829351305961609
# LOSS train 0.005317868369624753 valid 0.06204115976923289
# Training vs. Validation Loss {'Training': 0.005317868369624753, 'Validation': 0.06204115976923289} 280
# Training vs. Validation accuracy {'Training': 0.999018669128418, 'Validation': 0.9829351305961609} 280
# Stoping at epoch 279,minimum: 0.013651841525188502
# Epoch 280:
# Accuracy train:1.0, val:0.9863481521606445
# LOSS train 0.005847999028656676 valid 0.06915624993570575
# Training vs. Validation Loss {'Training': 0.005847999028656676, 'Validation': 0.06915624993570575} 281
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9863481521606445} 281
# Stoping at epoch 280,minimum: 0.013651841525188502
# Epoch 281:
# Accuracy train:0.999018669128418, val:0.9863481521606445
# LOSS train 0.002167396973583471 valid 0.06418257019155187
# Training vs. Validation Loss {'Training': 0.002167396973583471, 'Validation': 0.06418257019155187} 282
# Training vs. Validation accuracy {'Training': 0.999018669128418, 'Validation': 0.9863481521606445} 282
# Stoping at epoch 281,minimum: 0.013651841525188502
# Epoch 282:
# Accuracy train:1.0, val:0.9897611141204834
# LOSS train 0.005599814476087117 valid 0.062132850650958936
# Training vs. Validation Loss {'Training': 0.005599814476087117, 'Validation': 0.062132850650958936} 283
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9897611141204834} 283
# Stoping at epoch 282,minimum: 0.013651841525188502
# Epoch 283:
# Accuracy train:0.999018669128418, val:0.9829351305961609
# LOSS train 0.008795137074859948 valid 0.07583292973014129
# Training vs. Validation Loss {'Training': 0.008795137074859948, 'Validation': 0.07583292973014129} 284
# Training vs. Validation accuracy {'Training': 0.999018669128418, 'Validation': 0.9829351305961609} 284
# Stoping at epoch 283,minimum: 0.013651841525188502
# Epoch 284:
# Accuracy train:0.9960745573043823, val:0.979522168636322
# LOSS train 0.012650008813999683 valid 0.07029386945932907
# Training vs. Validation Loss {'Training': 0.012650008813999683, 'Validation': 0.07029386945932907} 285
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.979522168636322} 285
# Stoping at epoch 284,minimum: 0.013651841525188502
# Epoch 285:
# Accuracy train:1.0, val:0.9829351305961609
# LOSS train 0.020834399187571344 valid 0.06554626638541154
# Training vs. Validation Loss {'Training': 0.020834399187571344, 'Validation': 0.06554626638541154} 286
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9829351305961609} 286
# Stoping at epoch 285,minimum: 0.013651841525188502
# Epoch 286:
# Accuracy train:0.9970559477806091, val:0.9897611141204834
# LOSS train 0.012772717279753683 valid 0.06189863643303332
# Training vs. Validation Loss {'Training': 0.012772717279753683, 'Validation': 0.06189863643303332} 287
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9897611141204834} 287
# Stoping at epoch 286,minimum: 0.013651841525188502
# Epoch 287:
# Accuracy train:0.9970559477806091, val:0.9863481521606445
# LOSS train 0.006115491079981439 valid 0.06771350709236164
# Training vs. Validation Loss {'Training': 0.006115491079981439, 'Validation': 0.06771350709236164} 288
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9863481521606445} 288
# Stoping at epoch 287,minimum: 0.013651841525188502
# Epoch 288:
# Accuracy train:0.9960745573043823, val:0.9829351305961609
# LOSS train 0.009853121400038408 valid 0.08855680606273797
# Training vs. Validation Loss {'Training': 0.009853121400038408, 'Validation': 0.08855680606273797} 289
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9829351305961609} 289
# Stoping at epoch 288,minimum: 0.013651841525188502
# Epoch 289:
# Accuracy train:1.0, val:0.9829351305961609
# LOSS train 0.007288134755351796 valid 0.07203074290726012
# Training vs. Validation Loss {'Training': 0.007288134755351796, 'Validation': 0.07203074290726012} 290
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9829351305961609} 290
# Stoping at epoch 289,minimum: 0.013651841525188502
# Epoch 290:
# Accuracy train:1.0, val:0.9863481521606445
# LOSS train 0.0036575326294741198 valid 0.07556522204957143
# Training vs. Validation Loss {'Training': 0.0036575326294741198, 'Validation': 0.07556522204957143} 291
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9863481521606445} 291
# Stoping at epoch 290,minimum: 0.013651841525188502
# Epoch 291:
# Accuracy train:1.0, val:0.9829351305961609
# LOSS train 0.0036985675133809517 valid 0.08783506750773995
# Training vs. Validation Loss {'Training': 0.0036985675133809517, 'Validation': 0.08783506750773995} 292
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9829351305961609} 292
# Stoping at epoch 291,minimum: 0.013651841525188502
# Epoch 292:
# Accuracy train:0.9980372786521912, val:0.9863481521606445
# LOSS train 0.007829515352428783 valid 0.06576901056696698
# Training vs. Validation Loss {'Training': 0.007829515352428783, 'Validation': 0.06576901056696698} 293
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9863481521606445} 293
# Stoping at epoch 292,minimum: 0.013651841525188502
# Epoch 293:
# Accuracy train:0.999018669128418, val:0.9829351305961609
# LOSS train 0.004944434271937308 valid 0.08063052180579196
# Training vs. Validation Loss {'Training': 0.004944434271937308, 'Validation': 0.08063052180579196} 294
# Training vs. Validation accuracy {'Training': 0.999018669128418, 'Validation': 0.9829351305961609} 294
# Stoping at epoch 293,minimum: 0.013651841525188502
# Epoch 294:
# Accuracy train:1.0, val:0.9829351305961609
# LOSS train 0.003371928550992519 valid 0.06989784411269924
# Training vs. Validation Loss {'Training': 0.003371928550992519, 'Validation': 0.06989784411269924} 295
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9829351305961609} 295
# Stoping at epoch 294,minimum: 0.013651841525188502
# Epoch 295:
# Accuracy train:0.9980372786521912, val:0.9829351305961609
# LOSS train 0.005272570285272265 valid 0.07548860648215812
# Training vs. Validation Loss {'Training': 0.005272570285272265, 'Validation': 0.07548860648215812} 296
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9829351305961609} 296
# Stoping at epoch 295,minimum: 0.013651841525188502
# Epoch 296:
# Accuracy train:0.999018669128418, val:0.9897611141204834
# LOSS train 0.004872034248994448 valid 0.06892909586249729
# Training vs. Validation Loss {'Training': 0.004872034248994448, 'Validation': 0.06892909586249729} 297
# Training vs. Validation accuracy {'Training': 0.999018669128418, 'Validation': 0.9897611141204834} 297
# Stoping at epoch 296,minimum: 0.013651841525188502
# Epoch 297:
# Accuracy train:0.9960745573043823, val:0.9863481521606445
# LOSS train 0.003577499751722476 valid 0.0635489946559522
# Training vs. Validation Loss {'Training': 0.003577499751722476, 'Validation': 0.0635489946559522} 298
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9863481521606445} 298
# Stoping at epoch 297,minimum: 0.013651841525188502
# Epoch 298:
# Accuracy train:0.9970559477806091, val:0.9829351305961609
# LOSS train 0.0061908869376146375 valid 0.06879875675838439
# Training vs. Validation Loss {'Training': 0.0061908869376146375, 'Validation': 0.06879875675838439} 299
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9829351305961609} 299
# Stoping at epoch 298,minimum: 0.013651841525188502
# Epoch 299:
# Accuracy train:0.9980372786521912, val:0.9829351305961609
# LOSS train 0.0038809809042364717 valid 0.07802987835087298
# Training vs. Validation Loss {'Training': 0.0038809809042364717, 'Validation': 0.07802987835087298} 300
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9829351305961609} 300
# Stoping at epoch 299,minimum: 0.013651841525188502
# tensor(0.9829)

# %%
list_label = label_dict_from_config_file("hand_gesture.yaml")
DATA_FOLDER_PATH="./data/"
testset = CustomImageDataset(os.path.join(DATA_FOLDER_PATH,"landmark_test.csv"))

# Test DataLoader instantiation
################## Your Code Here ################## Q6
test_loader = torch.utils.data.DataLoader(testset,batch_size=20,shuffle=False)
####################################################



network = NeuralNetwork()
network.load_state_dict(torch.load(best_model_path, weights_only=False))

network.eval()
acc_test = Accuracy(num_classes=len(list_label), task='MULTICLASS')
for i, test_data in enumerate(test_loader):
    test_input, test_label = test_data
    ################## Your Code Here ################## Q7
    '''Hoàn thành code bên dưới để  predict class của cử chỉ và update accuracy
    với kết quả predict và true labels
    '''
    preds =model(test_input)
    acc_test.update(preds,test_label)

    ####################################################

print(network.__class__.__name__)
print(f"Accuracy of model:{acc_test.compute().item()}")
print("========================================================================")
# Out:
# NeuralNetwork
# Accuracy of model:0.9763779640197754
# ========================================================================
